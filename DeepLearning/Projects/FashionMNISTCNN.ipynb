# %% [markdown]
# # step 1: import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout

# %% [markdown]
# # step 2: read data from file

# %%
data=pd.read_csv('datasets2/fashion-mnist_train.csv')
# random image
image1=data.iloc[5,1:].values
image1=image1.reshape(28,28)
plt.imshow(image1)
plt.show()
